# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt	


file = 'C:/Users/abesh/Downloads/cam_outs/2007_000063.npy'
orig = cv2.imread('C:/Users/abesh/Downloads/2007_000063.jpg')

img = np.load(file, allow_pickle=True)
img = img.item()['attn_highres']

# img = img.astype(np.uint8)

plt.imshow(img[0], cmap='viridis')
plt.show()
plt.imshow(img[1], cmap='viridis')
plt.show()
